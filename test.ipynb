# %%
import pandas as pd
import seaborn as sns

import src.cleaning as cleaning

# %%
# Sample to test functions:
sample = pd.read_csv('data/JC-202201-citibike-tripdata.csv').sample(20)

# %%
sample.head()
# Out:
#                 ride_id  rideable_type           started_at  \
# 13398  A01BD5F1510B52A9  electric_bike  2022-01-03 12:30:56
# 20566  E5B2B060D993199B   classic_bike  2022-01-19 16:22:12
# 11821  6C1855CE3F7B344A   classic_bike  2022-01-09 12:55:21
# 17593  CCF1F1F04461621C   classic_bike  2022-01-02 10:58:27
# 24022  59680257C94CA41C  electric_bike  2022-01-20 05:11:33
#
#                   ended_at                        start_station_name  \
# 13398  2022-01-03 12:33:24                              Morris Canal
# 20566  2022-01-19 16:30:10                           Adams St & 2 St
# 11821  2022-01-09 13:14:02  Hoboken Terminal - Hudson St & Hudson Pl
# 17593  2022-01-02 11:05:18                          Hudson St & 4 St
# 24022  2022-01-20 05:14:33                           McGinley Square
#
#       start_station_id      end_station_name end_station_id  start_lat  \
# 13398            JC072           Paulus Hook          JC002  40.712419
# ...

# %%
sample.describe()
# Out:
#        start_lat  start_lng    end_lat    end_lng     distance
# count  20.000000  20.000000  20.000000  20.000000    20.000000
# mean   40.729482 -74.043368  40.731777 -74.040361  1178.294465
# std     0.008425   0.012728   0.013089   0.010850   758.196134
# min    40.712419 -74.067622  40.712419 -74.063913   214.823905
# 25%    40.724882 -74.047820  40.721619 -74.044460   686.639746
# 50%    40.728170 -74.040821  40.729060 -74.038913  1049.494683
# 75%    40.735938 -74.033346  40.741069 -74.032906  1412.941882
# max    40.746413 -74.027781  40.754530 -74.024020  3463.239900

# %%
# Started at and ended at should be in date format:
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 13398 to 4318
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             20 non-null     object
#  1   rideable_type       20 non-null     object
#  2   started_at          20 non-null     object
#  3   ended_at            20 non-null     object
#  4   start_station_name  20 non-null     object
#  5   start_station_id    20 non-null     object
#  6   end_station_name    20 non-null     object
#  7   end_station_id      20 non-null     object
#  8   start_lat           20 non-null     float64
#  9   start_lng           20 non-null     float64
#  10  end_lat             20 non-null     float64
#  11  end_lng             20 non-null     float64
#  12  member_casual       20 non-null     object
#  13  distance            20 non-null     float64
# dtypes: float64(5), object(9)
# memory usage: 2.3+ KB

# %%
sample = cleaning.trip_distance(sample)
sample.head()
# Out:
#                 ride_id  rideable_type           started_at  \
# 13398  A01BD5F1510B52A9  electric_bike  2022-01-03 12:30:56
# 20566  E5B2B060D993199B   classic_bike  2022-01-19 16:22:12
# 11821  6C1855CE3F7B344A   classic_bike  2022-01-09 12:55:21
# 17593  CCF1F1F04461621C   classic_bike  2022-01-02 10:58:27
# 24022  59680257C94CA41C  electric_bike  2022-01-20 05:11:33
#
#                   ended_at                        start_station_name  \
# 13398  2022-01-03 12:33:24                              Morris Canal
# 20566  2022-01-19 16:30:10                           Adams St & 2 St
# 11821  2022-01-09 13:14:02  Hoboken Terminal - Hudson St & Hudson Pl
# 17593  2022-01-02 11:05:18                          Hudson St & 4 St
# 24022  2022-01-20 05:14:33                           McGinley Square
#
#       start_station_id      end_station_name end_station_id  start_lat  \
# 13398            JC072           Paulus Hook          JC002  40.712419
# ...
